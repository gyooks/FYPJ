# %%
# !pip install tensorflow opencv-python-headless numpy scikit-learn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.72.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import glob
import time

# Define the Drive location where the dataset is already stored
extracted_dir = '/content/drive/My Drive/fyp dataset egogesture'

# Verify the directory exists
if os.path.exists(extracted_dir):
    print(f"Extracted directory found: {extracted_dir}")
    # Force refresh of directory listing
    time.sleep(2)  # Delay to ensure sync
    print(f"Contents of {extracted_dir}: {os.listdir(extracted_dir)}")

    # Verify videos folder
    videos_dir = os.path.join(extracted_dir, 'videos')
    if os.path.exists(videos_dir):
        video_files = glob.glob(os.path.join(videos_dir, '*'))
        print(f"Videos folder contains {len(video_files)} items (subfolders/files):")
        for file in video_files[:5]:  # Show first 5 for brevity
            print(f"  - {os.path.basename(file)}")
        if len(video_files) > 5:
            print(f"  - ... and {len(video_files) - 5} more items")
    else:
        print("Videos folder not found.")

    # Verify labels folder with recursive search
    labels_dir = os.path.join(extracted_dir, 'labels')
    print(f"Checking labels directory: {labels_dir}")
    if os.path.exists(labels_dir):
        print(f"Labels directory exists. Contents: {os.listdir(labels_dir)}")
        # Check all files in labels and subdirectories
        all_label_files = glob.glob(os.path.join(labels_dir, '**'), recursive=True)
        print(f"All files/folders in labels (including subdirectories): {len(all_label_files)}")
        for file in all_label_files[:5]:  # Show first 5 for brevity
            print(f"  - {os.path.basename(file)} (full path: {file})")
        if len(all_label_files) > 5:
            print(f"  - ... and {len(all_label_files) - 5} more items")
        # Check for .csv files recursively
        label_csv_files = glob.glob(os.path.join(labels_dir, '**', '*.csv'), recursive=True)
        print(f"Total .csv files in labels: {len(label_csv_files)}")
        for file in label_csv_files[:5]:  # Show first 5 for brevity
            print(f"  - {os.path.basename(file)} (full path: {file})")
        if len(label_csv_files) > 5:
            print(f"  - ... and {len(label_csv_files) - 5} more files")
        if len(label_csv_files) != 8:  # Adjust based on expected number
            print(f"Warning: Expected 8 .csv files based on screenshot, but found {len(label_csv_files)}.")
    else:
        print("Labels folder not found. Directory does not exist.")
else:
    print("Extracted directory not found. Ensure the 'fyp dataset egogesture' folder is correctly set up in Google Drive and Drive is mounted.")
# Out:
# Extracted directory found: /content/drive/My Drive/fyp dataset egogesture
# Contents of /content/drive/My Drive/fyp dataset egogesture: ['labels', 'videos', 'all_features.npy', 'gesture_recognition_model.h5', 'label_map.npy', 'unique_labels.npy']
# Videos folder contains 5 items (subfolders/files):
#   - videos_1-001
#   - videos_2-002
#   - videos_3-004
#   - videos_4-003
#   - videos_5-003
# Checking labels directory: /content/drive/My Drive/fyp dataset egogesture/labels
# Labels directory exists. Contents: ['subject08', 'subject13', 'subject09', 'subject06', 'subject14', 'subject15', 'subject12', 'subject10', 'subject11', 'subject07', 'subject18', 'subject22', 'subject21', 'subject20', 'subject25', 'subject24', 'subject23', 'subject17', 'subject19', 'subject16', 'subject31', 'subject26', 'subject27', 'subject35', 'subject32', 'subject29', 'subject33', 'subject34', 'subject28', 'subject30', 'subject45', 'subject39', 'subject40', 'subject37', 'subject43', 'subject42', 'subject41', 'subject36', 'subject44', 'subject38', 'subject47', 'subject49', 'subject46', 'subject48', 'subject50']
# All files/folders in labels (including subdirectories): 2189
#   -  (full path: /content/drive/My Drive/fyp dataset egogesture/labels/)
#   - subject08 (full path: /content/drive/My Drive/fyp dataset egogesture/labels/subject08)
#   - Scene6 (full path: /content/drive/My Drive/fyp dataset egogesture/labels/subject08/Scene6)
#   - Group1.csv (full path: /content/drive/My Drive/fyp dataset egogesture/labels/subject08/Scene6/Group1.csv)
#   - Group5.csv (full path: /content/drive/My Drive/fyp dataset egogesture/labels/subject08/Scene6/Group5.csv)
#   - ... and 2184 more items
# Total .csv files in labels: 1878
#   - Group1.csv (full path: /content/drive/My Drive/fyp dataset egogesture/labels/subject08/Scene6/Group1.csv)
#   - Group5.csv (full path: /content/drive/My Drive/fyp dataset egogesture/labels/subject08/Scene6/Group5.csv)
#   - Group2.csv (full path: /content/drive/My Drive/fyp dataset egogesture/labels/subject08/Scene6/Group2.csv)
#   - Group7.csv (full path: /content/drive/My Drive/fyp dataset egogesture/labels/subject08/Scene6/Group7.csv)
#   - Group4.csv (full path: /content/drive/My Drive/fyp dataset egogesture/labels/subject08/Scene6/Group4.csv)
#   - ... and 1873 more files
# Warning: Expected 8 .csv files based on screenshot, but found 1878.

# %%
import pandas as pd
import glob
import os

annotations_dir = '/content/drive/My Drive/fyp dataset egogesture/labels'
videos_dir = '/content/drive/My Drive/fyp dataset egogesture/videos'
desired_labels = [10, 11, 57, 58, 46, 36]

# Minimal directory checks
print(f"Checking directories...")
if not os.path.exists(annotations_dir):
    print(f"Error: Annotations directory {annotations_dir} does not exist.")
if not os.path.exists(videos_dir):
    print(f"Error: Videos directory {videos_dir} does not exist.")

all_annotations = []
for ann_file in glob.glob(os.path.join(annotations_dir, '**', '*.csv'), recursive=True):
    try:
        sample = pd.read_csv(ann_file, nrows=1, sep=',')
        header = 0
        if not sample.iloc[0].astype(str).str.match(r'^\\d+(\\.\\d+)?$').all():
            header = None

        annotations = pd.read_csv(ann_file, sep=',', names=['label', 'start_frame', 'end_frame'], header=header)
        annotations['label'] = pd.to_numeric(annotations['label'], errors='coerce')
        annotations = annotations.dropna(subset=['label'])
        annotations['start_frame'] = pd.to_numeric(annotations['start_frame'], errors='coerce')
        annotations['end_frame'] = pd.to_numeric(annotations['end_frame'], errors='coerce')
        annotations = annotations.dropna(subset=['start_frame', 'end_frame'])

        filtered = annotations[annotations['label'].isin(desired_labels)]
        if not filtered.empty:
            video_base = os.path.basename(ann_file).replace('Group', 'rgb').replace('.csv', '.avi')
            all_annotations.append(filtered.assign(video=video_base))
    except Exception as e:
        print(f"Error loading {ann_file}: {e}")

if all_annotations:
    all_annotations = pd.concat(all_annotations, ignore_index=True)
    print(f"Cell executed successfully. Total combined annotations: {len(all_annotations)}")
else:
    print("Cell executed, but no annotations loaded.")
# Out:
# Checking directories...
# Cell executed successfully. Total combined annotations: 1597

# %%
import cv2
import numpy as np
import os
import glob
import pandas as pd

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Define paths
extracted_dir = '/content/drive/My Drive/fyp dataset egogesture'
annotations_dir = os.path.join(extracted_dir, 'labels')
videos_dir = os.path.join(extracted_dir, 'videos')
feature_save_dir = extracted_dir

# Load and filter annotations
desired_labels = [10, 11, 57, 58, 46, 36]
all_annotations = []

print(f"Checking annotations directory: {annotations_dir}")
if os.path.exists(annotations_dir):
    print(f"Annotations directory exists. Contents: {os.listdir(annotations_dir)}")
else:
    print(f"Error: Annotations directory {annotations_dir} does not exist.")

print(f"Checking videos directory: {videos_dir}")
if os.path.exists(videos_dir):
    print(f"Videos directory exists. Contents: {os.listdir(videos_dir)}")
else:
    print(f"Error: Videos directory {videos_dir} does not exist.")

for ann_file in glob.glob(os.path.join(annotations_dir, '**', '*.csv'), recursive=True):
    print(f"Processing file: {ann_file}")
    try:
        sample = pd.read_csv(ann_file, nrows=1, sep=',')
        header = 0 if not sample.iloc[0].astype(str).str.match(r'^\d+(\.\d+)?$').all() else None
        annotations = pd.read_csv(ann_file, sep=',', names=['label', 'start_frame', 'end_frame'], header=header)

        annotations['label'] = pd.to_numeric(annotations['label'], errors='coerce')
        annotations = annotations.dropna(subset=['label'])
        annotations['start_frame'] = pd.to_numeric(annotations['start_frame'], errors='coerce')
        annotations['end_frame'] = pd.to_numeric(annotations['end_frame'], errors='coerce')
        annotations = annotations.dropna(subset=['start_frame', 'end_frame'])

        filtered = annotations[annotations['label'].isin(desired_labels)]
        if not filtered.empty:
            print(f"Filtered annotations from {ann_file}:")
            print(filtered.head())
            # Adjust video base to match case and structure
            video_base = os.path.basename(ann_file).replace('Group', 'rgb').replace('.csv', '.avi')
            subject_dir = os.path.basename(os.path.dirname(os.path.dirname(ann_file))).replace('subject', 'Subject')
            scene_dir = os.path.basename(os.path.dirname(ann_file))
            video_path = None
            for subdir in ['videos_1-001', 'videos_2-002', 'videos_3-004', 'videos_4-003', 'videos_5-003']:
                check_path = os.path.join(videos_dir, subdir, subject_dir, scene_dir, 'Color', video_base)
                if os.path.exists(check_path):
                    video_path = check_path
                    break
            if video_path is None:
                print(f"Error: Video file not found for {video_base} in any subdirectory. Skipping.")
                continue
            print(f"Assigning video path: {video_path}")
            all_annotations.append(filtered.assign(video=video_path))
        else:
            print(f"No matching labels found in {ann_file} from desired_labels: {desired_labels}")
    except Exception as e:
        print(f"Error loading or processing {ann_file}: {e}")

if all_annotations:
    all_annotations = pd.concat(all_annotations, ignore_index=True)
    print(f"\nTotal combined annotations: {len(all_annotations)}")
    print("Final combined annotations:")
    print(all_annotations.head())
else:
    all_annotations = pd.DataFrame(columns=['label', 'start_frame', 'end_frame', 'video'])
    print("\nNo annotations were loaded or filtered successfully from any file.")
    print("Final combined annotations is an empty DataFrame.")

def extract_sequences(annotations, videos_dir):
    sequences = []
    for index, row in annotations.iterrows():
        video_path = row['video']
        if not os.path.exists(video_path):
            print(f"Error: Video file not found at {video_path}. Skipping.")
            continue
        print(f"Attempting to open: {video_path}")
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            print(f"Error: Could not open video {video_path}")
            continue
        start_frame = int(row['start_frame'])
        end_frame = int(row['end_frame'])
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

        frames = []
        frame_count = 0
        target_frames = 30

        while frame_count < target_frames and cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                print(f"Warning: Reached end of video at frame {start_frame + frame_count} in {video_path}")
                break
            if start_frame + frame_count <= end_frame:
                frames.append(cv2.resize(frame, (64, 64)))
                frame_count += 1
            else:
                print(f"Warning: Reached end_frame {end_frame} at frame {start_frame + frame_count} in {video_path}")
                break

        cap.release()

        # Pad or truncate to exactly 30 frames
        if len(frames) < target_frames:
            print(f"Warning: Only {len(frames)} frames extracted from {video_path}. Padding with last frame.")
            last_frame = frames[-1] if frames else np.zeros((64, 64, 3), dtype=np.uint8)
            frames = frames + [last_frame] * (target_frames - len(frames))
        elif len(frames) > target_frames:
            print(f"Warning: Extracted {len(frames)} frames from {video_path}. Truncating to {target_frames}.")
            frames = frames[:target_frames]

        sequences.append(np.array(frames))

    return sequences

# Main execution block
if 'all_annotations' in globals() and not all_annotations.empty:
    print(f"Extracting sequences from {len(all_annotations)} annotations...")
    sequences = extract_sequences(all_annotations, videos_dir)
    print(f"Extracted {len(sequences)} sequences of 30 frames each.")
    # Save the extracted sequences
    os.makedirs(feature_save_dir, exist_ok=True)
    np.save(os.path.join(feature_save_dir, 'all_features.npy'), np.array(sequences))
    print(f"Features saved to: {os.path.join(feature_save_dir, 'all_features.npy')}")
else:
    print("Error: all_annotations is not defined or empty.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene1/Color/rgb2.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene1/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene1/Group1.csv:
#    label  start_frame  end_frame
# 9     57          803        843
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene1/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene1/Group4.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene1/Group4.csv:
#     label  start_frame  end_frame
# 0      10          111        158
# 11     11         1097       1140
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene1/Color/rgb4.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene1/Group7.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene1/Group7.csv:
#     label  start_frame  end_frame
# 10     36          990       1020
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene1/Color/rgb7.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene1/Group5.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene1/Group5.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene1/Group6.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene1/Group6.csv:
#    label  start_frame  end_frame
# 1     58          122        149
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene1/Color/rgb6.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene3/Group4.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene3/Group4.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene3/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene3/Group1.csv:
#    label  start_frame  end_frame
# 2     46          299        332
# 3     36          384        421
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene3/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene3/Group6.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene3/Group6.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene3/Group2.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene3/Group2.csv:
#    label  start_frame  end_frame
# 4     11          535        581
# 7     58          890        932
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene3/Color/rgb2.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene3/Group7.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene3/Group7.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene3/Group5.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene3/Group5.csv:
#    label  start_frame  end_frame
# 2     10          347        402
# 3     57          463        504
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene3/Color/rgb5.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene3/Group3.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene3/Group3.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene6/Group7.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene6/Group7.csv:
#    label  start_frame  end_frame
# 0     11          111        154
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene6/Color/rgb7.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene6/Group2.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene6/Group2.csv:
#    label  start_frame  end_frame
# 8     36         1019       1045
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene6/Color/rgb2.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene6/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene6/Group1.csv:
#    label  start_frame  end_frame
# 2     57          522        546
# 7     10         1052       1097
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene6/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene6/Group3.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene6/Group3.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene6/Group4.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene6/Group4.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene6/Group5.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene6/Group5.csv:
#     label  start_frame  end_frame
# 9      58         1085       1110
# 10     46         1178       1209
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene6/Color/rgb5.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene6/Group6.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene6/Group6.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene5/Group7.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene5/Group7.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene5/Group2.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene5/Group2.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene5/Group6.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene5/Group6.csv:
#     label  start_frame  end_frame
# 10     58         1033       1055
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene5/Color/rgb6.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene5/Group3.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene5/Group3.csv:
#    label  start_frame  end_frame
# 1     10          603        645
# 5     36         1063       1097
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene5/Color/rgb3.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene5/Group1.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene5/Group1.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene5/Group4.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene5/Group4.csv:
#    label  start_frame  end_frame
# 4     11          573        615
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene5/Color/rgb4.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene5/Group5.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene5/Group5.csv:
#     label  start_frame  end_frame
# 1      57          200        225
# 11     46         1430       1458
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene5/Color/rgb5.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene4/Group4.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene4/Group4.csv:
#    label  start_frame  end_frame
# 9     46          927        960
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene4/Color/rgb4.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene4/Group2.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene4/Group2.csv:
#    label  start_frame  end_frame
# 7     58          722        754
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene4/Color/rgb2.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene4/Group6.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene4/Group6.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene4/Group7.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene4/Group7.csv:
#     label  start_frame  end_frame
# 3      11          365        413
# 7      36          718        755
# 10     57          979       1030
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene4/Color/rgb7.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene4/Group5.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene4/Group5.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene4/Group3.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene4/Group3.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene4/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject28/Scene4/Group1.csv:
#    label  start_frame  end_frame
# 3     10          378        439
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject28/Scene4/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene1/Group2.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene1/Group2.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene1/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene1/Group1.csv:
#    label  start_frame  end_frame
# 7     11          750        797
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene1/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene1/Group7.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene1/Group7.csv:
#    label  start_frame  end_frame
# 6     58          630        647
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene1/Color/rgb7.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene1/Group6.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene1/Group6.csv:
#    label  start_frame  end_frame
# 5     10          683        735
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene1/Color/rgb6.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene1/Group5.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene1/Group5.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene1/Group4.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene1/Group4.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene1/Group3.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene1/Group3.csv:
#    label  start_frame  end_frame
# 0     57          108        135
# 2     46          316        347
# 8     36          910        940
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene1/Color/rgb3.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene4/Group5.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene4/Group5.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene4/Group2.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene4/Group2.csv:
#    label  start_frame  end_frame
# 7     46         1003       1035
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene4/Color/rgb2.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene4/Group6.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene4/Group6.csv:
#    label  start_frame  end_frame
# 6     36          734        765
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene4/Color/rgb6.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene4/Group1.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene4/Group1.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene4/Group3.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene4/Group3.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene4/Group7.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene4/Group7.csv:
#    label  start_frame  end_frame
# 1     58          243        262
# 8     11          939        985
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene4/Color/rgb7.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene4/Group4.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene4/Group4.csv:
#    label  start_frame  end_frame
# 7     10         1047       1097
# 9     57         1276       1310
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene4/Color/rgb4.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene5/Group6.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene5/Group6.csv:
#    label  start_frame  end_frame
# 1     36           53         79
# 6     11          458        488
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene5/Color/rgb6.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene5/Group5.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene5/Group5.csv:
#    label  start_frame  end_frame
# 3     58          316        339
# 8     10          724        817
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene5/Color/rgb5.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene5/Group7.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene5/Group7.csv:
#    label  start_frame  end_frame
# 9     57          846        872
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene5/Color/rgb7.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene5/Group3.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene5/Group3.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene5/Group2.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene5/Group2.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene5/Group4.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene5/Group4.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene5/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene5/Group1.csv:
#     label  start_frame  end_frame
# 11     46         1795       1830
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene5/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene6/Group6.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene6/Group6.csv:
#    label  start_frame  end_frame
# 4     36          354        378
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene6/Color/rgb6.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene6/Group7.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene6/Group7.csv:
#    label  start_frame  end_frame
# 5     46          547        572
# 8     58          723        745
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene6/Color/rgb7.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene6/Group4.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene6/Group4.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene6/Group1.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene6/Group1.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene6/Group3.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene6/Group3.csv:
#     label  start_frame  end_frame
# 10     57          744        759
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene6/Color/rgb3.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene6/Group5.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene6/Group5.csv:
#    label  start_frame  end_frame
# 8     10          666        722
# 9     11          756        786
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene6/Color/rgb5.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene6/Group2.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene6/Group2.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene3/Group2.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene3/Group2.csv:
#     label  start_frame  end_frame
# 10     11         1372       1417
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene3/Color/rgb2.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene3/Group3.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene3/Group3.csv:
#    label  start_frame  end_frame
# 6     57         1088       1123
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene3/Color/rgb3.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene3/Group6.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene3/Group6.csv:
#     label  start_frame  end_frame
# 11     10         1524       1579
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene3/Color/rgb6.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene3/Group4.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene3/Group4.csv:
#    label  start_frame  end_frame
# 4     58          932        953
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene3/Color/rgb4.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene3/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene3/Group1.csv:
#    label  start_frame  end_frame
# 3     46          420        453
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene3/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene3/Group7.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene3/Group7.csv:
#    label  start_frame  end_frame
# 2     36          272        314
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene3/Color/rgb7.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene3/Group5.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene3/Group5.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene2/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene2/Group1.csv:
#    label  start_frame  end_frame
# 3     11          466        523
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene2/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene2/Group6.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene2/Group6.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene2/Group7.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene2/Group7.csv:
#    label  start_frame  end_frame
# 0     10          129        169
# 8     57          964       1000
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene2/Color/rgb7.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene2/Group5.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene2/Group5.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene2/Group3.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene2/Group3.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene2/Group2.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene2/Group2.csv:
#     label  start_frame  end_frame
# 5      46          838        876
# 11     36         1492       1524
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene2/Color/rgb2.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene2/Group4.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject30/Scene2/Group4.csv:
#    label  start_frame  end_frame
# 4     58          552        572
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_3-004/Subject30/Scene2/Color/rgb4.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene1/Group5.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene1/Group5.csv:
#    label  start_frame  end_frame
# 1     46          218        255
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene1/Color/rgb5.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene1/Group7.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene1/Group7.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene1/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene1/Group1.csv:
#    label  start_frame  end_frame
# 3     57          498        530
# 6     36          879        916
# 9     58         1330       1355
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene1/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene1/Group2.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene1/Group2.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene1/Group6.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene1/Group6.csv:
#    label  start_frame  end_frame
# 5     10          693        760
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene1/Color/rgb6.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene1/Group3.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene1/Group3.csv:
#     label  start_frame  end_frame
# 11     11         1605       1704
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene1/Color/rgb3.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene1/Group4.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene1/Group4.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene5/Group7.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene5/Group7.csv:
#    label  start_frame  end_frame
# 3     11          234        266
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene5/Color/rgb7.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene5/Group2.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene5/Group2.csv:
#    label  start_frame  end_frame
# 7     36          447        469
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene5/Color/rgb2.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene5/Group5.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene5/Group5.csv:
#    label  start_frame  end_frame
# 2     57          202        216
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene5/Color/rgb5.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene5/Group6.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene5/Group6.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene5/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene5/Group1.csv:
#     label  start_frame  end_frame
# 11     58         1028       1050
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene5/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene5/Group3.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene5/Group3.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene5/Group4.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene5/Group4.csv:
#    label  start_frame  end_frame
# 2     46          281        307
# 8     10          744        779
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene5/Color/rgb4.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene4/Group7.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene4/Group7.csv:
#    label  start_frame  end_frame
# 3     10          418        462
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene4/Color/rgb7.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene4/Group4.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene4/Group4.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene4/Group5.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene4/Group5.csv:
#    label  start_frame  end_frame
# 1     57          202        222
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene4/Color/rgb5.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene4/Group2.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene4/Group2.csv:
#    label  start_frame  end_frame
# 1     58          183        206
# 3     11          386        428
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene4/Color/rgb2.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene4/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene4/Group1.csv:
#     label  start_frame  end_frame
# 8      36          932        972
# 11     46         1288       1329
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene4/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene4/Group6.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene4/Group6.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene4/Group3.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene4/Group3.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene2/Group2.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene2/Group2.csv:
#    label  start_frame  end_frame
# 6     36         1281       1312
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene2/Color/rgb2.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene2/Group4.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene2/Group4.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene2/Group5.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene2/Group5.csv:
#    label  start_frame  end_frame
# 6     57         1150       1181
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene2/Color/rgb5.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene2/Group3.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene2/Group3.csv:
#     label  start_frame  end_frame
# 12     46         1599       1643
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene2/Color/rgb3.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene2/Group6.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene2/Group6.csv:
#     label  start_frame  end_frame
# 12     10         1712       1765
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene2/Color/rgb6.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene2/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene2/Group1.csv:
#    label  start_frame  end_frame
# 0     58           94        131
# 4     11          665        743
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene2/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene6/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene6/Group1.csv:
#    label  start_frame  end_frame
# 0     36           38         54
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene6/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene6/Group5.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene6/Group5.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene6/Group3.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene6/Group3.csv:
#    label  start_frame  end_frame
# 5     10          435        462
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene6/Color/rgb3.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene6/Group2.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene6/Group2.csv:
#     label  start_frame  end_frame
# 9      46          616        638
# 10     57          702        708
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene6/Color/rgb2.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene6/Group7.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene6/Group7.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene6/Group4.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene6/Group4.csv:
#    label  start_frame  end_frame
# 2     58          170        190
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene6/Color/rgb4.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene6/Group6.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene6/Group6.csv:
#    label  start_frame  end_frame
# 8     11          540        570
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene6/Color/rgb6.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene3/Group1.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene3/Group1.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene3/Group3.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene3/Group3.csv:
#    label  start_frame  end_frame
# 8     10         1288       1338
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene3/Color/rgb3.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene3/Group2.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene3/Group2.csv:
#    label  start_frame  end_frame
# 0     11          108        152
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene3/Color/rgb2.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene3/Group7.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene3/Group7.csv:
#    label  start_frame  end_frame
# 1     36          177        218
# 2     58          295        320
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene3/Color/rgb7.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene3/Group4.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene3/Group4.csv:
#    label  start_frame  end_frame
# 4     46          416        451
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene3/Color/rgb4.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene3/Group5.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene3/Group5.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene3/Group6.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject45/Scene3/Group6.csv:
#    label  start_frame  end_frame
# 4     57          471        508
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject45/Scene3/Color/rgb6.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene2/Group5.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene2/Group5.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene2/Group3.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene2/Group3.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene2/Group2.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene2/Group2.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene2/Group6.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene2/Group6.csv:
#    label  start_frame  end_frame
# 8     57          860        888
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_4-003/Subject39/Scene2/Color/rgb6.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene2/Group4.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene2/Group4.csv:
#    label  start_frame  end_frame
# 3     46          555        594
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_4-003/Subject39/Scene2/Color/rgb4.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene2/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene2/Group1.csv:
#     label  start_frame  end_frame
# 4      58          946        967
# 6      36         1147       1183
# 10     11         1565       1616
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_4-003/Subject39/Scene2/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene2/Group7.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene2/Group7.csv:
#    label  start_frame  end_frame
# 1     10          230        273
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_4-003/Subject39/Scene2/Color/rgb7.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene4/Group3.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene4/Group3.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene4/Group2.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene4/Group2.csv:
#    label  start_frame  end_frame
# 5     10          632        675
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_4-003/Subject39/Scene4/Color/rgb2.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene4/Group6.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene4/Group6.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene4/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene4/Group1.csv:
#     label  start_frame  end_frame
# 11     36         1088       1122
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_4-003/Subject39/Scene4/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene4/Group5.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene4/Group5.csv:
#     label  start_frame  end_frame
# 2      11          337        378
# 5      58          666        683
# 8      57          968        999
# 10     46         1133       1178
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_4-003/Subject39/Scene4/Color/rgb5.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene4/Group7.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene4/Group7.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene4/Group4.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene4/Group4.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene5/Group3.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene5/Group3.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene5/Group6.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene5/Group6.csv:
#    label  start_frame  end_frame
# 7     11          415        458
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_4-003/Subject39/Scene5/Color/rgb6.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene5/Group7.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene5/Group7.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene5/Group5.csv
# No matching labels found in /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene5/Group5.csv from desired_labels: [10, 11, 57, 58, 46, 36]
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene5/Group1.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene5/Group1.csv:
#     label  start_frame  end_frame
# 3      57          299        329
# 10     58          773        802
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_4-003/Subject39/Scene5/Color/rgb1.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene5/Group2.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene5/Group2.csv:
#    label  start_frame  end_frame
# 7     46          460        496
# Assigning video path: /content/drive/My Drive/fyp dataset egogesture/videos/videos_4-003/Subject39/Scene5/Color/rgb2.avi
# Processing file: /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene5/Group4.csv
# Filtered annotations from /content/drive/My Drive/fyp dataset egogesture/labels/subject39/Scene5/Group4.csv:
#    label  start_frame  end_frame
# 3     10          334        376
# 6     36          508        542
# ...
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene2/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene2/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene2/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene2/Color/rgb6.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene2/Color/rgb6.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene2/Color/rgb1.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene5/Color/rgb7.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene5/Color/rgb7.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene5/Color/rgb1.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene5/Color/rgb2.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene5/Color/rgb6.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene5/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene4/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene4/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene4/Color/rgb3.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene4/Color/rgb2.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene4/Color/rgb6.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene4/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene6/Color/rgb1.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene6/Color/rgb2.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene6/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene6/Color/rgb6.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene6/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject46/Scene6/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene2/Color/rgb7.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene2/Color/rgb6.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene2/Color/rgb3.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene2/Color/rgb3.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene2/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene2/Color/rgb2.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene3/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene3/Color/rgb6.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene3/Color/rgb7.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene3/Color/rgb3.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene3/Color/rgb1.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene3/Color/rgb1.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene1/Color/rgb7.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene1/Color/rgb3.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene1/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene1/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene1/Color/rgb1.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene1/Color/rgb1.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene4/Color/rgb6.avi
# Warning: Reached end_frame 345 at frame 346 in /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene4/Color/rgb6.avi
# Warning: Only 22 frames extracted from /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene4/Color/rgb6.avi. Padding with last frame.
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene4/Color/rgb3.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene4/Color/rgb3.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene4/Color/rgb3.avi
# Warning: Reached end_frame 976 at frame 977 in /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene4/Color/rgb3.avi
# Warning: Only 24 frames extracted from /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene4/Color/rgb3.avi. Padding with last frame.
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene4/Color/rgb2.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene4/Color/rgb4.avi
# Warning: Reached end_frame 1011 at frame 1012 in /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene4/Color/rgb4.avi
# Warning: Only 27 frames extracted from /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene4/Color/rgb4.avi. Padding with last frame.
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene6/Color/rgb7.avi
# Warning: Reached end_frame 389 at frame 390 in /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene6/Color/rgb7.avi
# Warning: Only 24 frames extracted from /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene6/Color/rgb7.avi. Padding with last frame.
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene6/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene6/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene6/Color/rgb1.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene6/Color/rgb1.avi
# Warning: Reached end_frame 551 at frame 552 in /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene6/Color/rgb1.avi
# Warning: Only 24 frames extracted from /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene6/Color/rgb1.avi. Padding with last frame.
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene6/Color/rgb5.avi
# Warning: Reached end_frame 606 at frame 607 in /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene6/Color/rgb5.avi
# Warning: Only 26 frames extracted from /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene6/Color/rgb5.avi. Padding with last frame.
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene5/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene5/Color/rgb4.avi
# Warning: Reached end_frame 1563 at frame 1564 in /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene5/Color/rgb4.avi
# Warning: Only 25 frames extracted from /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene5/Color/rgb4.avi. Padding with last frame.
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene5/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene5/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene5/Color/rgb2.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject48/Scene5/Color/rgb3.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene1/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene1/Color/rgb6.avi
# Warning: Reached end_frame 1189 at frame 1190 in /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene1/Color/rgb6.avi
# Warning: Only 26 frames extracted from /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene1/Color/rgb6.avi. Padding with last frame.
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene1/Color/rgb2.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene1/Color/rgb2.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene1/Color/rgb2.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene1/Color/rgb7.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene5/Color/rgb7.avi
# Warning: Reached end_frame 250 at frame 251 in /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene5/Color/rgb7.avi
# Warning: Only 22 frames extracted from /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene5/Color/rgb7.avi. Padding with last frame.
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene5/Color/rgb2.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene5/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene5/Color/rgb3.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene5/Color/rgb6.avi
# Warning: Reached end_frame 90 at frame 91 in /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene5/Color/rgb6.avi
# Warning: Only 20 frames extracted from /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene5/Color/rgb6.avi. Padding with last frame.
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene5/Color/rgb6.avi
# Warning: Reached end_frame 409 at frame 410 in /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene5/Color/rgb6.avi
# Warning: Only 28 frames extracted from /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene5/Color/rgb6.avi. Padding with last frame.
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene2/Color/rgb6.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene2/Color/rgb2.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene2/Color/rgb7.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene2/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene2/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene2/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene4/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene4/Color/rgb6.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene4/Color/rgb6.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene4/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene4/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene4/Color/rgb3.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene6/Color/rgb3.avi
# Warning: Reached end_frame 606 at frame 607 in /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene6/Color/rgb3.avi
# Warning: Only 23 frames extracted from /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene6/Color/rgb3.avi. Padding with last frame.
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene6/Color/rgb3.avi
# Warning: Reached end_frame 797 at frame 798 in /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene6/Color/rgb3.avi
# Warning: Only 21 frames extracted from /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene6/Color/rgb3.avi. Padding with last frame.
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene6/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene6/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene6/Color/rgb4.avi
# Warning: Reached end_frame 556 at frame 557 in /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene6/Color/rgb4.avi
# Warning: Only 16 frames extracted from /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene6/Color/rgb4.avi. Padding with last frame.
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene6/Color/rgb6.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene3/Color/rgb5.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene3/Color/rgb4.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene3/Color/rgb6.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene3/Color/rgb6.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene3/Color/rgb3.avi
# Attempting to open: /content/drive/My Drive/fyp dataset egogesture/videos/videos_5-003/Subject50/Scene3/Color/rgb3.avi
# Extracted 1542 sequences of 30 frames each.
# Features saved to: /content/drive/My Drive/fyp dataset egogesture/all_features.npy

# %%
def extract_optical_flow_features(sequence):
    flow_features = []
    for i in range(len(sequence) - 1):
        frame1 = cv2.cvtColor(sequence[i], cv2.COLOR_BGR2GRAY)
        frame2 = cv2.cvtColor(sequence[i + 1], cv2.COLOR_BGR2GRAY)
        flow = cv2.calcOpticalFlowFarneback(frame1, frame2, None, 0.5, 3, 15, 3, 5, 1.2, 0)
        magnitude, angle = cv2.cartToPolar(flow[..., 0], flow[..., 1])
        flow_features.append(np.array([np.mean(magnitude), np.mean(angle)]))
    return np.array(flow_features)

if 'sequences' in globals() and sequences:
    print(f"Extracting features from {len(sequences)} sequences...")
    all_features = []
    for i, seq in enumerate(sequences):
        features = extract_optical_flow_features(seq)
        all_features.append(features)
    all_features = np.array(all_features)
    # Save to feature_save_dir
    save_path = os.path.join(feature_save_dir, 'all_features.npy')
    np.save(save_path, all_features)
    print(f"Total features shape: {all_features.shape}")
    print(f"Features saved as {save_path}.")
else:
    print("Error: No sequences extracted.")
# Out:
# Extracting features from 1542 sequences...
# Total features shape: (1542, 29, 2)
# Features saved as /content/drive/My Drive/fyp dataset egogesture/all_features.npy.

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import glob
import os
from sklearn.utils import class_weight
from scipy.ndimage.interpolation import shift

# Define the directory where features were saved
feature_save_dir = '/content/drive/My Drive/fyp dataset egogesture'

# Load features from the Drive location
print(f"Attempting to load feature files from: {feature_save_dir}")
feature_files = glob.glob(os.path.join(feature_save_dir, 'all_features.npy'))

print(f"Found {len(feature_files)} feature files.")
if not feature_files:
    print("Error: No feature files found. Please ensure the previous extraction and saving step completed successfully.")
    all_features = []
else:
    all_features = []
    for file in feature_files:
        try:
            batch_data = np.load(file, allow_pickle=True)
            all_features.append(batch_data)
            print(f"Loaded {file} with shape {batch_data.shape}.")
            # Verify frame count consistency
            if batch_data.shape[1] != 30:  # Expecting 30 frames per sequence
                print(f"Warning: Expected 30 frames, got {batch_data.shape[1]} in {file}.")
        except Exception as e:
            print(f"Error loading {file}: {e}")

if all_features:
    try:
        all_features = np.concatenate(all_features) if len(all_features) > 1 else all_features[0]
        print(f"Successfully loaded and concatenated {len(all_features)} feature sequences.")
        print(f"Shape of consolidated features: {all_features.shape}")

        if 'all_annotations' in globals() and all_features.size > 0 and not all_annotations.empty:
            if len(all_features) != len(all_annotations):
                print(f"Warning: Number of extracted feature sequences ({len(all_features)}) does not match the number of annotations ({len(all_annotations)}).")
                min_len = min(len(all_features), len(all_annotations))
                all_features = all_features[:min_len]
                all_annotations = all_annotations.iloc[:min_len]
                print(f"Truncating features and annotations to match length: {min_len}")

            X = all_features
            y = all_annotations['label'].values

            unique_labels = np.unique(y)
            label_map = {label: i for i, label in enumerate(unique_labels)}
            y_mapped = np.array([label_map[label] for label in y])
            y_categorical = to_categorical(y_mapped, num_classes=len(unique_labels))

            # Check class distribution
            class_weights = class_weight.compute_class_weight('balanced', classes=unique_labels, y=y)
            class_weight_dict = dict(enumerate(class_weights))

            print(f"Shape of X before split: {X.shape}")
            print(f"Shape of y_categorical before split: {y_categorical.shape}")
            print(f"Class weights: {class_weight_dict}")

            if X.shape[0] < 2 or y_categorical.shape[0] < 2:
                print("Error: Not enough samples to perform train/test split.")
            else:
                X_train, X_test, y_train, y_test = train_test_split(X, y_categorical, test_size=0.2, random_state=42, stratify=y_mapped)

                print(f"Shape of X_train: {X_train.shape}")
                print(f"Shape of X_test: {X_test.shape}")
                print(f"Shape of y_train: {y_train.shape}")
                print(f"Shape of y_test: {y_test.shape}")

                expected_input_shape = (X_train.shape[1], X_train.shape[2])
                print(f"LSTM expected input shape: {expected_input_shape}")
                if X_train.shape[1] != 29 and X_train.shape[1] != 30:
                    print(f"Warning: Unexpected feature shape {X_train.shape}. LSTM input shape might be incorrect.")

                # Enhanced model architecture
                model = Sequential([
                    LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]), kernel_regularizer='l2'),
                    BatchNormalization(),
                    Dropout(0.3),
                    LSTM(64),
                    BatchNormalization(),
                    Dropout(0.3),
                    Dense(32, activation='relu', kernel_regularizer='l2'),
                    BatchNormalization(),
                    Dropout(0.3),
                    Dense(len(unique_labels), activation='softmax')
                ])

                model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

                if X_train.shape[0] < 32:
                    print(f"Warning: Training set size ({X_train.shape[0]}) is less than batch size (32). Adjusting batch_size.")
                    batch_size = max(1, X_train.shape[0])
                else:
                    batch_size = 32

                # Callbacks
                early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
                reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001)

                # Optional data augmentation
                # def augment_sequence(seq, shift_amount=1):
                #     return shift(seq, [0, shift_amount, 0], mode='constant', cval=0.0)
                # X_train_aug = np.concatenate([X_train, np.array([augment_sequence(seq) for seq in X_train])])
                # y_train_aug = np.concatenate([y_train, y_train])
                # X_test_aug = np.array([augment_sequence(seq) for seq in X_test])
                # y_test_aug = y_test
                # history = model.fit(X_train_aug, y_train_aug, epochs=50, batch_size=batch_size, validation_data=(X_test_aug, y_test_aug),
                #                   class_weight=class_weight_dict, verbose=1, callbacks=[early_stopping, reduce_lr])
                history = model.fit(X_train, y_train, epochs=50, batch_size=batch_size, validation_data=(X_test, y_test),
                                  class_weight=class_weight_dict, verbose=1, callbacks=[early_stopping, reduce_lr])

                test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
                print(f"Test accuracy: {test_accuracy:.4f}")
                print(f"Test loss: {test_loss:.4f}")
                print(f"Best validation loss: {min(history.history['val_loss'])}")

                os.makedirs(feature_save_dir, exist_ok=True)
                model_save_path = os.path.join(feature_save_dir, 'gesture_recognition_model.h5')
                label_map_save_path = os.path.join(feature_save_dir, 'label_map.npy')
                unique_labels_save_path = os.path.join(feature_save_dir, 'unique_labels.npy')

                model.save(model_save_path)
                np.save(label_map_save_path, label_map)
                np.save(unique_labels_save_path, unique_labels)
                print(f"Model saved to: {model_save_path}")
                print(f"Label map saved to: {label_map_save_path}")
                print(f"Unique labels saved to: {unique_labels_save_path}")
                print("Model and metadata saved.")
        else:
            print("Error: Data not available for training (all_annotations empty or no features loaded).")
    except ValueError as ve:
        print(f"ValueError during concatenation or processing: {ve}")
    except Exception as e:
        print(f"An unexpected error occurred during model training: {e}")
else:
    print("Error: No features loaded from files. Cannot proceed with training.")
# Out:
# Attempting to load feature files from: /content/drive/My Drive/fyp dataset egogesture
# Found 1 feature files.
# Loaded /content/drive/My Drive/fyp dataset egogesture/all_features.npy with shape (1542, 29, 2).
# Warning: Expected 30 frames, got 29 in /content/drive/My Drive/fyp dataset egogesture/all_features.npy.
# Successfully loaded and concatenated 1542 feature sequences.
# Shape of consolidated features: (1542, 29, 2)
# Shape of X before split: (1542, 29, 2)
# Shape of y_categorical before split: (1542, 6)
# Class weights: {0: np.float64(1.00390625), 1: np.float64(0.9961240310077519), 2: np.float64(1.0), 3: np.float64(1.00390625), 4: np.float64(1.007843137254902), 5: np.float64(0.9884615384615385)}
# Shape of X_train: (1233, 29, 2)
# Shape of X_test: (309, 29, 2)
# Shape of y_train: (1233, 6)
# Shape of y_test: (309, 6)
# LSTM expected input shape: (29, 2)
# <ipython-input-116-3216187579>:11: DeprecationWarning: Please import `shift` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.interpolation import shift
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 11s 119ms/step - accuracy: 0.1639 - loss: 2.8460 - val_accuracy: 0.1812 - val_loss: 2.2383 - learning_rate: 0.0010
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.1609 - loss: 2.6043 - val_accuracy: 0.1553 - val_loss: 2.2350 - learning_rate: 0.0010
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.1898 - loss: 2.4601 - val_accuracy: 0.1812 - val_loss: 2.2222 - learning_rate: 0.0010
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.2017 - loss: 2.4612 - val_accuracy: 0.1780 - val_loss: 2.2203 - learning_rate: 0.0010
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.1866 - loss: 2.3832 - val_accuracy: 0.1618 - val_loss: 2.2070 - learning_rate: 0.0010
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.1906 - loss: 2.3299 - val_accuracy: 0.1683 - val_loss: 2.1831 - learning_rate: 0.0010
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.2018 - loss: 2.3335 - val_accuracy: 0.1650 - val_loss: 2.1706 - learning_rate: 0.0010
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.1926 - loss: 2.2752 - val_accuracy: 0.1650 - val_loss: 2.1900 - learning_rate: 0.0010
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.1765 - loss: 2.2400 - val_accuracy: 0.1650 - val_loss: 2.1307 - learning_rate: 0.0010
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.1948 - loss: 2.1915 - val_accuracy: 0.1294 - val_loss: 2.1278 - learning_rate: 0.0010
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.2315 - loss: 2.1293 - val_accuracy: 0.1489 - val_loss: 2.1183 - learning_rate: 0.0010
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.1948 - loss: 2.1307 - val_accuracy: 0.1748 - val_loss: 2.0992 - learning_rate: 0.0010
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.2146 - loss: 2.1006 - val_accuracy: 0.1424 - val_loss: 2.0963 - learning_rate: 0.0010
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.1986 - loss: 2.0813 - val_accuracy: 0.1521 - val_loss: 2.0581 - learning_rate: 0.0010
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.2044 - loss: 2.0412 - val_accuracy: 0.1424 - val_loss: 2.0482 - learning_rate: 0.0010
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - accuracy: 0.2445 - loss: 1.9858 - val_accuracy: 0.1618 - val_loss: 2.0237 - learning_rate: 0.0010
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.2270 - loss: 1.9904 - val_accuracy: 0.1845 - val_loss: 2.0441 - learning_rate: 0.0010
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.2072 - loss: 2.0154 - val_accuracy: 0.1424 - val_loss: 2.0767 - learning_rate: 0.0010
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2149 - loss: 1.9832 - val_accuracy: 0.1909 - val_loss: 1.9906 - learning_rate: 0.0010
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.2292 - loss: 1.9698 - val_accuracy: 0.1618 - val_loss: 2.0422 - learning_rate: 0.0010
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - accuracy: 0.2244 - loss: 1.9518 - val_accuracy: 0.1877 - val_loss: 1.9809 - learning_rate: 0.0010
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.2252 - loss: 1.9200 - val_accuracy: 0.1489 - val_loss: 1.9775 - learning_rate: 0.0010
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.2120 - loss: 1.9144 - val_accuracy: 0.1683 - val_loss: 1.9374 - learning_rate: 0.0010
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2469 - loss: 1.9040 - val_accuracy: 0.1845 - val_loss: 1.9789 - learning_rate: 0.0010
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.2146 - loss: 1.9033 - val_accuracy: 0.1877 - val_loss: 1.9187 - learning_rate: 0.0010
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.2191 - loss: 1.8898 - val_accuracy: 0.1877 - val_loss: 1.9898 - learning_rate: 0.0010
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2228 - loss: 1.8668 - val_accuracy: 0.1553 - val_loss: 1.9334 - learning_rate: 0.0010
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.2359 - loss: 1.8623 - val_accuracy: 0.1812 - val_loss: 1.9523 - learning_rate: 0.0010
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2303 - loss: 1.8492 - val_accuracy: 0.1618 - val_loss: 2.0325 - learning_rate: 0.0010
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 0.2254 - loss: 1.8515 - val_accuracy: 0.1586 - val_loss: 1.9061 - learning_rate: 0.0010
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.2364 - loss: 1.8504 - val_accuracy: 0.1877 - val_loss: 1.9085 - learning_rate: 0.0010
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.2469 - loss: 1.7989 - val_accuracy: 0.1392 - val_loss: 1.9257 - learning_rate: 0.0010
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2371 - loss: 1.8358 - val_accuracy: 0.1974 - val_loss: 1.9371 - learning_rate: 0.0010
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.2299 - loss: 1.8201 - val_accuracy: 0.1553 - val_loss: 1.9335 - learning_rate: 0.0010
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - accuracy: 0.2241 - loss: 1.8158 - val_accuracy: 0.1715 - val_loss: 1.8815 - learning_rate: 0.0010
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2330 - loss: 1.8147 - val_accuracy: 0.1327 - val_loss: 1.9079 - learning_rate: 0.0010
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.2864 - loss: 1.7832 - val_accuracy: 0.1424 - val_loss: 1.8893 - learning_rate: 0.0010
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2458 - loss: 1.7890 - val_accuracy: 0.1650 - val_loss: 1.8725 - learning_rate: 0.0010
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.2670 - loss: 1.7845 - val_accuracy: 0.1650 - val_loss: 1.8905 - learning_rate: 0.0010
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.2425 - loss: 1.7902 - val_accuracy: 0.1812 - val_loss: 1.8968 - learning_rate: 0.0010
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.2539 - loss: 1.7737 - val_accuracy: 0.1650 - val_loss: 1.8694 - learning_rate: 0.0010
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2636 - loss: 1.7528 - val_accuracy: 0.1586 - val_loss: 1.8649 - learning_rate: 0.0010
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.2778 - loss: 1.7731 - val_accuracy: 0.1650 - val_loss: 1.8937 - learning_rate: 0.0010
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.2543 - loss: 1.7698 - val_accuracy: 0.1553 - val_loss: 1.8949 - learning_rate: 0.0010
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - accuracy: 0.2548 - loss: 1.7819 - val_accuracy: 0.1715 - val_loss: 1.8746 - learning_rate: 0.0010
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.2882 - loss: 1.7254 - val_accuracy: 0.1521 - val_loss: 1.8831 - learning_rate: 0.0010
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2620 - loss: 1.7388 - val_accuracy: 0.1748 - val_loss: 1.8580 - learning_rate: 0.0010
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.2633 - loss: 1.7488 - val_accuracy: 0.1650 - val_loss: 1.9499 - learning_rate: 0.0010
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.2811 - loss: 1.7402 - val_accuracy: 0.1748 - val_loss: 1.8942 - learning_rate: 0.0010
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - accuracy: 0.2727 - loss: 1.7295 - val_accuracy: 0.1715 - val_loss: 1.8975 - learning_rate: 0.0010
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test accuracy: 0.1748
# Test loss: 1.8580
# Best validation loss: 1.857964038848877
# Model saved to: /content/drive/My Drive/fyp dataset egogesture/gesture_recognition_model.h5
# Label map saved to: /content/drive/My Drive/fyp dataset egogesture/label_map.npy
# Unique labels saved to: /content/drive/My Drive/fyp dataset egogesture/unique_labels.npy
# Model and metadata saved.

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)
cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
print("Confusion Matrix:\n", cm)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# Confusion Matrix:
#  [[23  0 11 11  3  3]
#  [20  1 11 15  4  1]
#  [21  3  7 11  5  5]
#  [15  1 14 10  2  9]
#  [15  0 10 12  3 11]
#  [15  1 12 12  2 10]]

# %%
import os
print(os.listdir('/content/'))
# Out:
# ['.config', 'drive', 'sample_data']

# %%
from google.colab import files
files.download('gesture_recognition_model.h5')
files.download('label_map.npy')
files.download('unique_labels.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-119-44621690> in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 files.download('gesture_recognition_model.h5')
#       3 files.download('label_map.npy')
#       4 files.download('unique_labels.npy')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: gesture_recognition_model.h5

# %%
import psutil
print(psutil.virtual_memory())
